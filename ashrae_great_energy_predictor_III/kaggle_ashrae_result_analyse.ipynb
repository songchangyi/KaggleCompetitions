# %%
# green  : the best score obtained
# blue   : 2nd and 3rd scores
# yellow : final scores choosed

from IPython.display import Image
Image(filename='./img/private_res.jpg')

# %% [markdown]
# ### Analyse

# %% [markdown]
# Do :
#
# 1.blend with more models if :
# - they have scores at the same level
# - they are trained with different approchs
#
# Not do :
#
# 1.calculate blend weights in a very precised way, like SGD
#
# 2.just seek a good result in public lb
